# %%
import pandas as pd
from dotenv import load_dotenv
import os
from os.path import join, dirname

# %%
import tweepy as tw
from textblob import TextBlob

# %%
from tweepy.api import API
from tweepy.auth import AppAuthHandler, OAuthHandler
from tweepy.cache import Cache, FileCache, MemoryCache
from tweepy.cursor import Cursor
from tweepy.error import RateLimitError, TweepError
from tweepy.models import DirectMessage, Friendship, ModelFactory, SavedSearch, SearchResults, Status, User
from tweepy.streaming import Stream, StreamListener

# %%
load_dotenv()

consumer_key = os.environ.get("consumer_key")
consumer_secret = os.environ.get("consumer_secret")
access_token = os.environ.get("access_token")
access_token_secret = os.environ.get("access_token_secret")

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %%
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth =  tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name="Santi_ABASCAL", count=5)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("5 recent tweets:\n")
for tweet in tweets[:5]:
    print(tweet.text)
# Out:
# Number of tweets extracted: 5.
#
# 5 recent tweets:
#
# ...y siguen las colas en Ávila para el acto de VOX #EspañaSiempre https://t.co/SZcSQovKIE
# Colas en Ávila una hora antes del inicio del acto de VOX #EspañaSiempre #Ávila #AhoraVOX https://t.co/DJ6xZGrF5K
# Absurda noticia. No hay ninguna costa que pagar porque todo lo que han hecho nuestros abogados @Ortega_Smith y… https://t.co/GFfip9DY08
# El próximo lunes 21-O estaré en el acto público de VOX en ALBACETE. #EspañaSiempre #Albacete #VOX https://t.co/wj2tb39AzV
# RT @vox_es: PP, PSOE y Ciudadanos: distintos caminos, mismos objetivos. En lo político, en lo social y ahora también en lo lingüístico, imp…

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  ...y siguen las colas en Ávila para el acto de...
# 1  Colas en Ávila una hora antes del inicio del a...
# 2  Absurda noticia. No hay ninguna costa que paga...
# 3  El próximo lunes 21-O estaré en el acto públic...
# 4  RT @vox_es: PP, PSOE y Ciudadanos: distintos c...

# %% [markdown]
# # por hastag #

# %%
import csv

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %%
#####Santiago_abascal
# Open/Create a file to append data
csvFile = open('Abascal13.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)

for tweet in tw.Cursor(api.search,q="#SantiagoAbascalEH",
                           lang="es",
                           since="2019-10-10").items(1000):
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet])
# Out:
# 2019-10-17 08:35:17 RT @JoseMa_Llanos: .@Santi_ABASCAL ahora en El Hormiguero de @antena3com  Todos los espectadores pueden ver a un gran hombre, a un político…
# 2019-10-17 08:18:47 RT @madrid_vox: 📺 Ya está disponible la entrevista a @Santi_ABASCAL, presidente de @vox_es, en @El_Hormiguero:
#
# Grande gracias a Abascal, a su saber estar y compostura, no a Pa…
# 2019-10-13 17:31:38 RT @AgustinRosety: Hoy Pablo Motos en @Elhormiguero_A3 ha querido hacerse perdonar el “crimen” de entrevistar a @Santi_ABASCAL haciéndole u…
# 2019-10-13 17:30:02 RT @CasoAislado_Es: A ver si se enteran los progres. Pablo Motos no lo ha podido explicar mejor. #SantiagoAbascalEH. "No sería democrático…
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# /usr/lib/python3/dist-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1716             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1717         self._raise_ssl_error(self._ssl, result)
#    1718
#
# /usr/lib/python3/dist-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1522         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1523             raise WantReadError()
#    1524         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-dea252ee1f44> in <module>
#       7 for tweet in tw.Cursor(api.search,q="#SantiagoAbascalEH",
#       8                            lang="es",
# ----> 9                            since="2019-10-10").items(1000):
#      10     print (tweet.created_at, tweet.text)
#      11     csvWriter.writerow([tweet])
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~/.local/lib/python3.6/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~/.local/lib/python3.6/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     562         else:
#     563             while not is_fp_closed(self._fp):
# --> 564                 data = self.read(amt=amt, decode_content=decode_content)
#     565
#     566                 if data:
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# /usr/lib/python3.6/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /usr/lib/python3.6/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
users_locs = [[tweet.user.screen_name, tweet.user.name, tweet.created_at, tweet.user.location, tweet.text, tweet.coordinates] for tweet in tweets]

# %%
df = pd.read_csv("Abascal13.csv", header = None)

# %%
df
# Out:
#                                                      0
# 0    Status(_api=<tweepy.api.API object at 0x7f3538...
# 1    Status(_api=<tweepy.api.API object at 0x7f3538...
# 2    Status(_api=<tweepy.api.API object at 0x7f3538...
# 3    Status(_api=<tweepy.api.API object at 0x7f3538...
# 4    Status(_api=<tweepy.api.API object at 0x7f3538...
# ..                                                 ...
# 542  Status(_api=<tweepy.api.API object at 0x7f3538...
# 543  Status(_api=<tweepy.api.API object at 0x7f3538...
# 544  Status(_api=<tweepy.api.API object at 0x7f3538...
# 545  Status(_api=<tweepy.api.API object at 0x7f3538...
# 546  Status(_api=<tweepy.api.API object at 0x7f3538...
#
# [547 rows x 1 columns]

# %%
tweets = tw.Cursor(api.search,
              q="Abascal",
              lang="es").items(1000)

# %%
tweets

# %%
users_locs = [[tweet.user.screen_name, tweet.user.location, tweet.text] for tweet in tweets]

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location", "tweet"])
tweet_text
# Out:
#                 user                     location  \
# 0       CasviFactory
# 1        JonnyRasero              Castamere Ruins
# 2     andremaquieira
# 3            XavMasR    l'Hospitalet de Llobregat
# 4             sysco5  Una Autonomia Galactica 155
# ..               ...                          ...
# 995         Amelycie                       Madrid
# 996  manuelajaravid1               Toledo, España
# 997    escofet_jaume
# 998     MarkusReilly                   Katalonien
# 999       scarmen173
#
#                                                  tweet
# 0    "Las falsedades de Abascal y Espinosa de los M...
# 1    RT @AntonioMaestre: A ver si se atreve a conte...
# 2    RT @maribelfdez2: Santi Abascal: Ayer ganaste ...
# 3    RT @either_mark: "P***S C*******S, le metí así...
# 4    RT @asmapar: @albasidera @jordiborras La ultra...
# ..                                                 ...
# 995  RT @Foxxthefox: Abascal dice, que va a recurri...
# 996  RT @ana_gandi: Los votantes del PSOE van a ten...
# 997  RT @either_mark: "P***S C*******S, le metí así...
# 998  RT @either_mark: "P***S C*******S, le metí así...
# 999  @Miguichiqui @Santi_ABASCAL Mi madre en paz de...
#
# [1000 rows x 3 columns]

# %% [markdown]
# # popularidad

# %%
palabra = input("Buscar: ")
numero_de_Tweets = int(input(u"Número de tweets a capturar: "))
lenguaje = input("Idioma [es/en]:")
# Out:
# Buscar: Abascal
# Número de tweets a capturar: 1000
# Idioma [es/en]:es

# %%
def ObtenerTweets(palabra="Abascal",times=1000,leguanje="es"):
    #Se define las listas que capturan la popularidad
    popularidad_list = []
    numeros_list = []
    numero = 1
    for tweet in tweepy.Cursor(api.search, palabra, lang=lenguaje, since="2019-10-10", until="2019-10-11").items(numero_de_Tweets):
        try:
            #Se toma el texto, se hace el analisis de sentimiento
            #y se agrega el resultado a las listas
            analisis = TextBlob(tweet.text)
            analisis = analisis.sentiment
            popularidad = analisis.polarity
            popularidad_list.append(popularidad)
            numeros_list.append(numero)
            numero = numero + 1

        except tweepy.TweepError as e:
            print(e.reason)

        except StopIteration:
            break
    return (numeros_list,popularidad_list,numero)

# %%
texto="ivanedlm trending topics on twitter right now pablo motorcycles abascal how good we are going to have fun"

# %%
blob_texto = TextBlob(texto)

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/angel/nltk_data...
# True

# %%
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid=SentimentIntensityAnalyzer()

# %%
sid.polarity_scores(texto)
# Out:
# {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.7351}

# %%
blob_texto.translat
e(to="en")
# Out:
# TextBlob("ivanedlm trending topics on twitter right now pablo motorcycles abascal how good we are going to have fun")

# %%
def GraficarDatos(numeros_list,popularidad_list,numero):
    axes = plt.gca()
    axes.set_ylim([-1, 2])
    
    plt.scatter(numeros_list, popularidad_list)
    popularidadPromedio = (sum(popularidad_list))/(len(popularidad_list))
    popularidadPromedio = "{0:.0f}%".format(popularidadPromedio * 100)
    #time  = datetime.now().strftime("A : %H:%M\n El: %m-%d-%y")
    plt.text(0, 1.25, 
             "Sentimiento promedio:  " + str(popularidadPromedio) + "\n", #+ time, 
             fontsize=12, 
             bbox = dict(facecolor='none', 
                         edgecolor='black', 
                         boxstyle='square, pad = 1'))
    
    plt.title("Sentimientos sobre " + palabra + " en twitter")
    plt.xlabel("Numero de tweets")
    plt.ylabel("Sentimiento")
    plt.show()

# %%
 numeros_list,popularidad_list,numero = ObtenerTweets(palabra,numero_de_Tweets,lenguaje)

# %%
numero
# Out:
# 1001

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
 GraficarDatos(numeros_list,popularidad_list,numero)
