# %%
import pandas as pd
from dotenv import load_dotenv
import os
from os.path import join, dirname

# %%
from __future__ import unicode_literals
import csv
import tweepy as tw
from tweepy.api import API
from tweepy.auth import AppAuthHandler, OAuthHandler
from tweepy.cache import Cache, FileCache, MemoryCache
from tweepy.cursor import Cursor
from tweepy.error import RateLimitError, TweepError
from tweepy.models import DirectMessage, Friendship, ModelFactory, SavedSearch, SearchResults, Status, User
from tweepy.streaming import Stream, StreamListener

# %%
load_dotenv()

consumer_key = os.environ.get("consumer_key")
consumer_secret = os.environ.get("consumer_secret")
access_token = os.environ.get("access_token")
access_token_secret = os.environ.get("access_token_secret")

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %%
csvFile = open('errejon.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

for tweet in tw.Cursor(api.search,
                           q = "#ErrejonEH",
                         since = "2019-10-16",
                          until = "2019-10-17",
                           lang = "es").items(1000):

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.user.screen_name, tweet.created_at, tweet.user.location, tweet.text])
   # print tweet.created_at, tweet.text
csvFile.close()

# %%
df_erre = pd.read_csv("errejon.csv")

# %%
df_erre.columns=["user", "fecha", "location", "tweet"]

# %%
df_erre
# Out:
#                 user                fecha    location  \
# 0      Cacique_bitch  2019-10-15 23:58:45      España
# 1      Cacique_bitch  2019-10-15 23:58:37      España
# 2      AlvaroVazkez4  2019-10-15 23:58:35      España
# 3      Cacique_bitch  2019-10-15 23:58:24      España
# 4           godoitos  2019-10-15 23:57:33  Manchester
# ...              ...                  ...         ...
# 10001      reysito29  2019-10-16 06:40:24         NaN
# 10002    jjRaysa1111  2019-10-16 06:40:16         NaN
# 10003   ZurimaSocias  2019-10-16 06:38:23         NaN
# 10004   ZurimaSocias  2019-10-16 06:37:45         NaN
# 10005  GViernesTrozo  2019-10-16 06:37:00         NaN
#
#                                                    tweet
# 0      RT @Javi_alm: Hoy parece que a Pablo Motos no ...
# 1      RT @MariaJamardoC: El candidato de Más País ha...
# 2      RT @MariaJamardoC: El candidato de Más País ha...
# 3      RT @vargasotero: #ErrejónEH Pablo, preguntale ...
# 4      RT @MasRetiro_: ‼️Sentencia y Cataluña\n\nPor ...
# ...                                                  ...
# 10001  RT @abc_es: Íñigo Errejón: «No apoyaré a Pedro...
# 10002  RT @COPE: Errejón se muestra a favor de los in...
# 10003  RT @masmadridjoven: "Estoy orgulloso de ser co...
# 10004  RT @Kamchatka_H: La gente se pregunta por qué ...
# 10005  #ErrejónEH dice lo primero, que va a decir que...
#
# [10006 rows x 4 columns]

# %%
df_erre.duplicated().value_counts()
# Out:
# True     7388
# False    2618
# dtype: int64

# %%
df_erre = df_erre.drop_duplicates()

# %%
df_erre
# Out:
#                  user                fecha                        location  \
# 0       Cacique_bitch  2019-10-15 23:58:45                          España
# 1       Cacique_bitch  2019-10-15 23:58:37                          España
# 2       AlvaroVazkez4  2019-10-15 23:58:35                          España
# 3       Cacique_bitch  2019-10-15 23:58:24                          España
# 4            godoitos  2019-10-15 23:57:33                      Manchester
# ...               ...                  ...                             ...
# 4741     MasHortaleza  2019-10-17 01:19:32               Hortaleza, Madrid
# 4742        josiderus  2019-10-17 00:53:59                 Linares, España
# 4953   miryamreissner  2019-10-16 15:27:37  Alicante, Comunidad Valenciana
# 7006  negocios_varios  2019-10-17 14:21:49                             NaN
# 7007           chunta  2019-10-17 14:08:20                          Aragón
#
#                                                   tweet
# 0     RT @Javi_alm: Hoy parece que a Pablo Motos no ...
# 1     RT @MariaJamardoC: El candidato de Más País ha...
# 2     RT @MariaJamardoC: El candidato de Más País ha...
# 3     RT @vargasotero: #ErrejónEH Pablo, preguntale ...
# 4     RT @MasRetiro_: ‼️Sentencia y Cataluña\n\nPor ...
# ...                                                 ...
# 4741  RT @MasPais_Es: 🎥 Las pensiones tienen que est...
# 4742  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
# 4953  RT @criticayobra: Denunciando la basura y sacá...
# 7006  RT @LfilodelabrechA: #ErrejonEH Este hombre es...
# 7007  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
#
# [2618 rows x 4 columns]

# %% [markdown]
# # TRADUCIR

# %%
df = pd.read_csv("pp.csv")

# %%
df.columns=["user", "fecha", "location", "tweet"]

# %%
df
# Out:
#                  user                fecha                        location  \
# 0        JusaFernando  2019-10-10 23:59:59                             NaN
# 1           EEvadidac  2019-10-10 23:59:58                             NaN
# 2           Jaferez76  2019-10-10 23:59:56                             NaN
# 3               gcs9s  2019-10-10 23:59:56                             NaN
# 4         ColchoneroG  2019-10-10 23:59:56                             NaN
# ...               ...                  ...                             ...
# 7261    ECruz99705878  2019-10-11 21:52:01                             NaN
# 7262    MCastillaCort  2019-10-11 21:51:54               Cortegana-Sevilla
# 7263       FarrasJose  2019-10-11 21:51:51                             NaN
# 7264  joseJim29925153  2019-10-11 21:51:50  Las Palmas de Gran Canaria, Es
# 7265        Ferdiaz65  2019-10-11 21:51:48                             NaN
#
#                                                   tweet
# 0     RT @ManhattanManOne: No he podido ver el progr...
# 1     RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero...
# 2     RT @elentirvigo: Pablo Motos es el perfecto pr...
# 3     RT @_Sapientiae: Cuando te mola más un comunis...
# 4     RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero...
# ...                                                 ...
# 7261  RT @cid_lauri: #PabloMotos, te dejo el vídeo a...
# 7262  RT @vox_es: 🗣️ @Santi_ABASCAL "Ayer conseguimo...
# 7263  RT @vox_es: 🗣️ @Santi_ABASCAL "Ayer conseguimo...
# 7264  RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero...
# 7265  RT @diostuitero: Gracias a la entrevista a #Sa...
#
# [7266 rows x 4 columns]

# %%
from __future__ import print_function
from googleapiclient.discovery import build

#set the translate Service
service = build('translate', 'v2',
        developerKey='AIzaSyATvPo4AatfEvI-NW-stjnnz1YkP5hsD2c')

#This just creates a simple function we can use later.
def translateText(wordList, sourceLang="es", targetLang="en"):
    result=service.translations().list(
        source=sourceLang,
        target=targetLang,
        q=wordList
        ).execute()
    return result

# %%
x= 0
y = 100

# %%
wordList= list(df_erre.tweet[x:y])
sourceLang = "es"
targetLang = "en"

# %%
traduccion = translateText(wordList, sourceLang, targetLang)

# %%
def columna_traducida(traduccion):
    lista = []
    for x in traduccion.values():
        for y in x:
             lista.append(y.values())
    lista_2= []
    for x in lista:
        for y in x:
            lista_2.append(y)
    return lista_2

# %%
x += 100
y += 100

# %%
#columna_final_erre= columna_traducida(traduccion)

# %%
columna_final_erre += columna_traducida(traduccion)

# %%
len (columna_final_erre)
# Out:
# 2618

# %%
x
# Out:
# 2700

# %%
y
# Out:
# 2800

# %%
df_erre["columna_traducida"]= columna_final_erre
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_erre
# Out:
#                  user                fecha                        location  \
# 0       Cacique_bitch  2019-10-15 23:58:45                          España
# 1       Cacique_bitch  2019-10-15 23:58:37                          España
# 2       AlvaroVazkez4  2019-10-15 23:58:35                          España
# 3       Cacique_bitch  2019-10-15 23:58:24                          España
# 4            godoitos  2019-10-15 23:57:33                      Manchester
# ...               ...                  ...                             ...
# 4741     MasHortaleza  2019-10-17 01:19:32               Hortaleza, Madrid
# 4742        josiderus  2019-10-17 00:53:59                 Linares, España
# 4953   miryamreissner  2019-10-16 15:27:37  Alicante, Comunidad Valenciana
# 7006  negocios_varios  2019-10-17 14:21:49                             NaN
# 7007           chunta  2019-10-17 14:08:20                          Aragón
#
#                                                   tweet  \
# 0     RT @Javi_alm: Hoy parece que a Pablo Motos no ...
# 1     RT @MariaJamardoC: El candidato de Más País ha...
# 2     RT @MariaJamardoC: El candidato de Más País ha...
# 3     RT @vargasotero: #ErrejónEH Pablo, preguntale ...
# 4     RT @MasRetiro_: ‼️Sentencia y Cataluña\n\nPor ...
# ...                                                 ...
# 4741  RT @MasPais_Es: 🎥 Las pensiones tienen que est...
# 4742  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
# 4953  RT @criticayobra: Denunciando la basura y sacá...
# 7006  RT @LfilodelabrechA: #ErrejonEH Este hombre es...
# 7007  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
#
#                                       columna_traducida
# 0     RT @Javi_alm: Today it seems that Pablo Motos ...
# 1     RT @MariaJamardoC: The candidate of More Count...
# 2     RT @MariaJamardoC: The candidate of More Count...
# 3     RT @vargasotero: # ErrejónEH Pablo, ask him wh...
# 4     RT @MasRetiro_:‼ ️Sentencia y Cataluña Above t...
# ...                                                 ...
# 4741  RT @MasPais_Es: 🎥 Pensions must be shielded in...
# 4742  RT @MasPais_Es: 🎥We need useful policy, one th...
# 4953  RT @criticayobra: Denouncing the trash and tak...
# 7006  RT @LfilodelabrechA: #ErrejonEH This man is dr...
# 7007  RT @MasPais_Es: 🎥We need useful policy, one th...
#
# [2618 rows x 5 columns]

# %%
#df.to_csv('df_FINAL_Abascal.csv', index=False)

# %% [markdown]
# # LIMPIEZA

# %%
import re
import string

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?¿\]\%', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

data_clean_1 = pd.DataFrame(df_erre.columna_traducida.apply(round1))

# %%
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…«»]', '', text)
    text = re.sub('\n', ' ', text)
    text = re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text)
    return text

round2 = lambda x: clean_text_round2(x)

data_clean = pd.DataFrame(data_clean_1.columna_traducida.apply(round2))
data_clean
# Out:
#                                       columna_traducida
# 0       javi alm  today it seems that pablo motos do...
# 1       mariajamardoc  the candidate of more country...
# 2       mariajamardoc  the candidate of more country...
# 3       vargasotero    errejneh pablo  ask him why h...
# 4       masretiro   sentencia y catalua above the wi...
# ...                                                 ...
# 4741    maspais es   pensions must be shielded in th...
# 4742    maspais es  we need useful policy  one that ...
# 4953    criticayobra  denouncing the trash and takin...
# 7006    lfilodelabrecha   errejoneh this man is drun...
# 7007    maspais es  we need useful policy  one that ...
#
# [2618 rows x 1 columns]

# %%
df_erre["columna_traducida"] = data_clean
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_erre
# Out:
#                  user                fecha                        location  \
# 0       Cacique_bitch  2019-10-15 23:58:45                          España
# 1       Cacique_bitch  2019-10-15 23:58:37                          España
# 2       AlvaroVazkez4  2019-10-15 23:58:35                          España
# 3       Cacique_bitch  2019-10-15 23:58:24                          España
# 4            godoitos  2019-10-15 23:57:33                      Manchester
# ...               ...                  ...                             ...
# 4741     MasHortaleza  2019-10-17 01:19:32               Hortaleza, Madrid
# 4742        josiderus  2019-10-17 00:53:59                 Linares, España
# 4953   miryamreissner  2019-10-16 15:27:37  Alicante, Comunidad Valenciana
# 7006  negocios_varios  2019-10-17 14:21:49                             NaN
# 7007           chunta  2019-10-17 14:08:20                          Aragón
#
#                                                   tweet  \
# 0     RT @Javi_alm: Hoy parece que a Pablo Motos no ...
# 1     RT @MariaJamardoC: El candidato de Más País ha...
# 2     RT @MariaJamardoC: El candidato de Más País ha...
# 3     RT @vargasotero: #ErrejónEH Pablo, preguntale ...
# 4     RT @MasRetiro_: ‼️Sentencia y Cataluña\n\nPor ...
# ...                                                 ...
# 4741  RT @MasPais_Es: 🎥 Las pensiones tienen que est...
# 4742  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
# 4953  RT @criticayobra: Denunciando la basura y sacá...
# 7006  RT @LfilodelabrechA: #ErrejonEH Este hombre es...
# 7007  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
#
#                                       columna_traducida
# 0       javi alm  today it seems that pablo motos do...
# 1       mariajamardoc  the candidate of more country...
# 2       mariajamardoc  the candidate of more country...
# 3       vargasotero    errejneh pablo  ask him why h...
# 4       masretiro   sentencia y catalua above the wi...
# ...                                                 ...
# 4741    maspais es   pensions must be shielded in th...
# 4742    maspais es  we need useful policy  one that ...
# 4953    criticayobra  denouncing the trash and takin...
# 7006    lfilodelabrecha   errejoneh this man is drun...
# 7007    maspais es  we need useful policy  one that ...
#
# [2618 rows x 5 columns]

# %% [markdown]
# # ANALISIS

# %%
from textblob import TextBlob

# %%
text = list(df_erre["columna_traducida"])

# %%
def fetch_sentiment_using_textblob(text):
    analysis = TextBlob(text)
    # set sentiment 
    if analysis.sentiment.polarity >= 0:
        return 'positive'
    else: 
        return 'negative'

# %%
resultado = []
for x in text:
    resultado.append(fetch_sentiment_using_textblob(x))
resultado
# Out:
# ['positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  ...]

# %%
df_erre["TextBlob"] = resultado
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_erre
# Out:
#                  user                fecha                        location  \
# 0       Cacique_bitch  2019-10-15 23:58:45                          España
# 1       Cacique_bitch  2019-10-15 23:58:37                          España
# 2       AlvaroVazkez4  2019-10-15 23:58:35                          España
# 3       Cacique_bitch  2019-10-15 23:58:24                          España
# 4            godoitos  2019-10-15 23:57:33                      Manchester
# ...               ...                  ...                             ...
# 4741     MasHortaleza  2019-10-17 01:19:32               Hortaleza, Madrid
# 4742        josiderus  2019-10-17 00:53:59                 Linares, España
# 4953   miryamreissner  2019-10-16 15:27:37  Alicante, Comunidad Valenciana
# 7006  negocios_varios  2019-10-17 14:21:49                             NaN
# 7007           chunta  2019-10-17 14:08:20                          Aragón
#
#                                                   tweet  \
# 0     RT @Javi_alm: Hoy parece que a Pablo Motos no ...
# 1     RT @MariaJamardoC: El candidato de Más País ha...
# 2     RT @MariaJamardoC: El candidato de Más País ha...
# 3     RT @vargasotero: #ErrejónEH Pablo, preguntale ...
# 4     RT @MasRetiro_: ‼️Sentencia y Cataluña\n\nPor ...
# ...                                                 ...
# 4741  RT @MasPais_Es: 🎥 Las pensiones tienen que est...
# 4742  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
# 4953  RT @criticayobra: Denunciando la basura y sacá...
# 7006  RT @LfilodelabrechA: #ErrejonEH Este hombre es...
# 7007  RT @MasPais_Es: 🎥Necesitamos política útil, aq...
#
#                                       columna_traducida  TextBlob
# 0       javi alm  today it seems that pablo motos do...  positive
# 1       mariajamardoc  the candidate of more country...  positive
# 2       mariajamardoc  the candidate of more country...  positive
# 3       vargasotero    errejneh pablo  ask him why h...  positive
# 4       masretiro   sentencia y catalua above the wi...  positive
# ...                                                 ...       ...
# 4741    maspais es   pensions must be shielded in th...  positive
# 4742    maspais es  we need useful policy  one that ...  positive
# 4953    criticayobra  denouncing the trash and takin...  positive
# 7006    lfilodelabrecha   errejoneh this man is drun...  negative
# 7007    maspais es  we need useful policy  one that ...  positive
#
# [2618 rows x 6 columns]

# %%
df_erre["TextBlob"].value_counts()
# Out:
# positive    2420
# negative     198
# Name: TextBlob, dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    4045
# True     3221
# dtype: int64

# %%
df_erre.to_csv('df_FINAL_Errejon.csv', index=False)

# %% [markdown]
# # NLTK

# %%
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid=SentimentIntensityAnalyzer()

# %%
df_Abascal = pd.read_csv("df_FINAL_Abascal.csv")

# %%
df_Errejon = pd.read_csv("df_FINAL_Errejon.csv")

# %%
texto = list(df_Abascal.columna_traducida)

# %%
texto_erre = list(df_Errejon.columna_traducida)

# %%
analisis = []
for x in texto_erre:
    analisis.append(sid.polarity_scores(x))

# %%
compound = []
for x in analisis:
    compound.append(x["compound"])

# %%
df_Errejon["compound"] = compound

# %%
df_Errejon.head()
# Out:
#             user                fecha    location  \
# 0  Cacique_bitch  2019-10-15 23:58:45      España
# 1  Cacique_bitch  2019-10-15 23:58:37      España
# 2  AlvaroVazkez4  2019-10-15 23:58:35      España
# 3  Cacique_bitch  2019-10-15 23:58:24      España
# 4       godoitos  2019-10-15 23:57:33  Manchester
#
#                                                tweet  \
# 0  RT @Javi_alm: Hoy parece que a Pablo Motos no ...
# 1  RT @MariaJamardoC: El candidato de Más País ha...
# 2  RT @MariaJamardoC: El candidato de Más País ha...
# 3  RT @vargasotero: #ErrejónEH Pablo, preguntale ...
# 4  RT @MasRetiro_: ‼️Sentencia y Cataluña\n\nPor ...
#
#                                    columna_traducida  TextBlob  compound
# 0    javi alm  today it seems that pablo motos do...  positive   -0.1779
# 1    mariajamardoc  the candidate of more country...  positive    0.4939
# 2    mariajamardoc  the candidate of more country...  positive    0.4939
# 3    vargasotero    errejneh pablo  ask him why h...  positive   -0.2023
# 4    masretiro   sentencia y catalua above the wi...  positive   -0.3197

# %%
df_Abascal.head()
# Out:
#            user                fecha location  \
# 0  JusaFernando  2019-10-10 23:59:59      NaN
# 1     EEvadidac  2019-10-10 23:59:58      NaN
# 2     Jaferez76  2019-10-10 23:59:56      NaN
# 3         gcs9s  2019-10-10 23:59:56      NaN
# 4   ColchoneroG  2019-10-10 23:59:56      NaN
#
#                                                tweet  \
# 0  RT @ManhattanManOne: No he podido ver el progr...
# 1  RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero...
# 2  RT @elentirvigo: Pablo Motos es el perfecto pr...
# 3  RT @_Sapientiae: Cuando te mola más un comunis...
# 4  RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero...
#
#                                    columna_traducida  TextBlob  compound
# 0    manhattanmanone  i could not see the program...  positive   -0.2529
# 1    vox en    santi abascal in  el hormiguero   ...  positive    0.1280
# 2    elentirvigo  pablo motos is the perfect prog...  positive    0.5719
# 3     sapientiae  when a communist who has no sha...  positive    0.5423
# 4    vox en    santi abascal in  el hormiguero   ...  negative    0.4168

# %%
df_Abascal.to_csv('df_FINAL_Abascal.csv', index=False)

# %%
df_Errejon.to_csv('df_FINAL_Errejon.csv', index=False)
