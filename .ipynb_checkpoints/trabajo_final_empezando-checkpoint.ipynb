# %%
import pandas as pd
from dotenv import load_dotenv
import os
from os.path import join, dirname

# %%
from __future__ import unicode_literals

# %%
import csv

# %%
import tweepy as tw

# %%
from tweepy.api import API
from tweepy.auth import AppAuthHandler, OAuthHandler
from tweepy.cache import Cache, FileCache, MemoryCache
from tweepy.cursor import Cursor
from tweepy.error import RateLimitError, TweepError
from tweepy.models import DirectMessage, Friendship, ModelFactory, SavedSearch, SearchResults, Status, User
from tweepy.streaming import Stream, StreamListener

# %%
from time import sleep
from datetime import datetime
from textblob import TextBlob 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
load_dotenv()

consumer_key = os.environ.get("consumer_key")
consumer_secret = os.environ.get("consumer_secret")
access_token = os.environ.get("access_token")
access_token_secret = os.environ.get("access_token_secret")

# %%
consumer_secret
# Out:
# '22gSlGa2BWUJU1fz7lwTAPwm3HCRdeCIBQeYarX5JszRslcJup'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %%
api.me().name
# Out:
# 'Angel Conesa'

# %%
search_words = "Abascal"
date_since = "2019-10-10"
date_until = "2019-10-11"

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="es",
              since=date_since,
              until=date_until).items(1000)
tweets

# %%
# Iterate and print tweets
for tweet in tweets:
       print (tweet.text)
# Out:
# RT @Lince7800: Escándalo en el CASO JUANA RIVAS.
# Espero que se tomen medidas urgentes contra la ministra Dolores Delgado.
# @ffmateobueno
# @v…
# RT @sanchezcastejon: Dice Abascal que la del PSOE es una historia criminal. Ni PP ni Cs salen a desmarcarse.
#
# Son PP y Cs quienes, abriénd…
# RT @AsimovDoctor: @El_Hormiguero @Santi_ABASCAL Solo espero que le preguntes a Pablo Iglesias sobre su apoyo y enaltecimiento al comunismo…
# RT @AnabelAlonso_of: "La mujer que quiera va a abortar pero no tendrá ayuda pública"
# Santiago Abascal.
# Osea, las que no tengan recursos se…
# RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# "Somos los únicos que no permitiríamos que salgan los violadores de mujeres de las cárcel…
# RT @FonsiLoaiza: Abascal se afilió al PP con 18 años y ha tenido 9 cargos. A sus 43 años no ha cotizado nunca fuera de la política, ha cobr…
# RT @wallstwolverine: En mi opinión balance positivo de la entrevista de Abascal. Hay que tener muy claro quién es el potencial votante de V…
# RT @SrMalafolla: Pablo Motos le pregunta a Abascal si su escolta lleva armas... No, son de la guardia suiza, llevan una lanza. #santiagoaba…
# RT @AnabelAlonso_of: "La mujer que quiera va a abortar pero no tendrá ayuda pública"
# Santiago Abascal.
# Osea, las que no tengan recursos se…
# RT @JuanfraEscudero: 🗣Santiago Abascal, @Santi_ABASCAL, está demostrando ser una persona con gran patriotismo, una persona buena, con un gr…
# RT @RodrigoDdeV13: Pero cómo es posible que entrevisten a Santiago Abascal en la tele??? Ni que fuera un terrorista...  #BoicotElHormiguero…
# RT @luciacuervas: Abascal: "Yo también represento al colectivo homosexual, no se por que se nos acusa de homófobos"  #SantiagoAbascalEH htt…
# RT @El_Hormiguero: .@Santi_ABASCAL nos habla sobre sus planteamientos de cara a las elecciones #SantiagoAbascalEH https://t.co/fkYK7Xik6z
# RT @SpainIsComing: Señor Don @Santi_ABASCAL , este señor dice que cuando le escucha le entran ganas de salir corriendo de España, ¿Podría u…
# RT @jgutierrez_vox: Parece ser que, siendo ya la 1:00, #SantiagoAbascalEH ha ganado, por una "ligera" ventaja, a #BoicotElHormiguero.
#
# Impr…
# @ViajeroMallorca @Santi_ABASCAL Vale, eso está genial pero espero que digas lo mismo de los otros líderes políticos cuando les toque ir.
# @Rojilloroy94 @FormulaTV Será por la insistencia de Pablo motos intentando poner en boca d @santi_ABASCAL cosas que no ha dicho.
# RT @casasola_89: Abascal: "Prefiero que un niño tenga un padre y una madre"
# Y yo prefiero que VOX no exista, pero...
# #BoicotElHormiguero #…
# RT @jmlopezzafra: Ha demostrado Abascal un gusto político exquisito al señalar a Girauta como aquel a quien ficharía por su talento para VO…
# RT @MediterraneoDGT: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# Cada vez que le des a 👉 #RT 🔄 un progre implosiona 🤮💥
#
# ¿Nos ayudas? 😏
#
# 📢 🇪🇸 @vox…
# RT @numer344: Corregidme si me equivoco, pero... ¿Aquellos que están pidiendo el boicot a Cuatro por entrevistar a Santiago Abascal, no son…
# RT @CasoAislado_Es: Contundentes palabras de Santiago Abascal, presidente de @vox_es, durante su intervención en El Hormiguero. #SantiagoAb…
# RT @El_Hormiguero: .@Santi_ABASCAL nos propone sus alternativas para Cataluña y su opinión sobre el cambio climático #SantiagoAbascalEH htt…
# RT @TIGRIDIA10: Hay opiniones que no comparto con Santiago Abascal ni por el forro, pero el hecho de dar su opinión sincera a sabiendas de…
# RT @CasoAislado_Es: A ver si se enteran los progres. Pablo Motos no lo ha podido explicar mejor. #SantiagoAbascalEH. "No sería democrático…
# RT @puigmelont: Abascal en El Hormiguero. https://t.co/cJBYHeLYp9
# RT @CLSaavedra1: #BoicotELHormiguero Como no voto a Vox, dudaba entre ver El Hormiguero y a Abascal, o mi serie de Netflix, pero los zurdos…
# RT @nadiafcb3: Santiago Abascal esta noche en el hormiguero, por una vez Pablo Motos no será el más tonto del programa 😃😃😃😃😃😃😃😃😃😃😃😃😃
# RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# "Defendería la frontera de Melilla con muros más grandes si es necesario y dando ayuda a…
# RT @eledhmel: .@Santi_ABASCAL: "Nosotros defendemos a las mujeres porque queremos que los violadores estén en la cárcel y no queremos que o…
# RT @puigmelont: Pedro Sánchez si fuese a El Hormiguero y le hiciesen la entrevista que le ha hecho Pablo Motos a Abascal. https://t.co/BSX0…
# RT @AnabelAlonso_of: "La mujer que quiera va a abortar pero no tendrá ayuda pública"
# Santiago Abascal.
# Osea, las que no tengan recursos se…
# RT @reeichelk: “No entiendo por qué nos llaman homófobos” -Santiago Abascal, 2019
# #SantiagoAbascalEH https://t.co/dEM3GKS6VR
# RT @RodrigoDdeV13: Y al que no le guste, que no vote Vox pero mediastintas y bienquedas ya tenemos muchos.  Abascal firme en sus opiniones.…
# RT @eledhmel: Pablo Motos: "Pareces tan bueno..."
# @Santi_ABASCAL: "Es que soy bueno".
#
# Doy fe.
#
# #SantiagoAbascalEH https://t.co/vZFouRWZrr
# RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# A Pablo Motos: "Estoy preocupado porque has dicho que tenemos sólo 2 diputados en el Cong…
# RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# "Somos los únicos que no permitiríamos que salgan los violadores de mujeres de las cárcel…
# RT @ivanypunto2014: Muy vergonzosa la entrevista. Sacando temas populistas y tratando de dejar mal a Santiago Abascal. Economia, trabajo, s…
# RT @AnabelAlonso_of: "La mujer que quiera va a abortar pero no tendrá ayuda pública"
# Santiago Abascal.
# Osea, las que no tengan recursos se…
# RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# "En Vistalegre apelé sobre todo a la reconciliación nacional. No puede venir nadie a dict…
# No comparto ningún ideal con VOX, porque me marginarían por 2 razones literalmente. Pero no podéis ir diciendo "boi… https://t.co/M6YcHD1mjY
# "Es que no entiendo por qué llevan a Abascal al Hormiguero." Bueno compañero, porque quieren hacer dinero. Porque v… https://t.co/Qgq5omiP49
# RT @SergioRevolS: Santiago Abascal equipara comunismo y fascismo, exactamente igual que la mitad de los progres que se autodenominan de izq…
# RT @Isrardi155: Insisto en que esto que ha dicho Abascal es muy importante y se ha hablado muy poco de ello. https://t.co/JitQu72EeB
# RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# "Yo me saqué la licencia de armas para proteger a mi padre en el País Vasco".
#
#  📢 #Santia…
# RT @LaResistencia: Abascal en El Hormiguero y Piqué en La Resistencia. Las dos Españas.
# RT @Hiiiipstah: A mí ni Vox ni Santiago Abascal me gustan. No los voto ni los votaría, pero como dice la famosa frase atribuida a Voltaire:…
# RT @LaResistencia: Abascal en El Hormiguero y Piqué en La Resistencia. Las dos Españas.
# RT @Tess_tuit: Antonio Maestre me ha bloqueado por decirle que ojalá Abascal se querelle contra él por compararlo con un asesino.
# Elisa Ben…
# RT @eledhmel: Los que piden #BoicotElHormiguero porque va @Santi_ABASCAL son los mismos que vieron encantados a Otegi en distintos programa…
# @JuanfraEscudero @Santi_ABASCAL Por suerte y gracias a Dios muchas no pensamos como vosotros
# RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜
#
# "Somos los únicos que no permitiríamos que salgan los violadores de mujeres de las cárcel…

# %%
new_search = search_words + " -filter:retweets"
new_search
# Out:
# 'Abascal -filter:retweets'

# %%
tweet.text
# Out:
# 'RT @vox_es: 📺 @Santi_ABASCAL en @El_Hormiguero 🐜\n\n"Somos los únicos que no permitiríamos que salgan los violadores de mujeres de las cárcel…'

# %%
tweets = [tweets.text for tweet in tweets]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-332993e18bd2> in <module>
# ----> 1 tweets = [tweets.text for tweet in tweets]
#
# <ipython-input-26-332993e18bd2> in <listcomp>(.0)
# ----> 1 tweets = [tweets.text for tweet in tweets]
#
# AttributeError: 'ItemIterator' object has no attribute 'text'

# %%
#tweets = tw.Cursor(api.search, q=new_search, lang="es", since=date_since).items(1000)

users_locs = [[tweet.user.screen_name, tweet.user.name, tweet.created_at, tweet.user.location, tweet.text] for tweet in tweets]
#users_locs
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# /usr/lib/python3/dist-packages/OpenSSL/SSL.py in do_handshake(self)
#    1807         result = _lib.SSL_do_handshake(self._ssl)
# -> 1808         self._raise_ssl_error(self._ssl, result)
#    1809
#
# /usr/lib/python3/dist-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1522         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1523             raise WantReadError()
#    1524         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     393             server_hostname=server_hostname,
# --> 394             ssl_context=context,
#     395         )
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     487                 if not util.wait_for_read(sock, sock.gettimeout()):
# --> 488                     raise timeout("select timed out")
#     489                 continue
#
# timeout: select timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
# --> 379             self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#     380             raise
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     330             raise ReadTimeoutError(
# --> 331                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     332             )
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#
# ReadTimeout: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-18-bb3a4f236fc1> in <module>
#       1 #tweets = tw.Cursor(api.search, q=new_search, lang="es", since=date_since).items(1000)
#       2
# ----> 3 users_locs = [[tweet.user.screen_name, tweet.user.name, tweet.created_at, tweet.user.location, tweet.text] for tweet in tweets]
#       4 #users_locs
#
# <ipython-input-18-bb3a4f236fc1> in <listcomp>(.0)
#       1 #tweets = tw.Cursor(api.search, q=new_search, lang="es", since=date_since).items(1000)
#       2
# ----> 3 users_locs = [[tweet.user.screen_name, tweet.user.name, tweet.created_at, tweet.user.location, tweet.text] for tweet in tweets]
#       4 #users_locs
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
# --> 191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     192
#     193                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~/.local/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "name", "created", "location", "tweet"])
tweet_text

# %%
all_tweets = tweet_text.tweet

# %%
sourceLang = "es"
targetLang = "en"

# %%
from __future__ import print_function
from googleapiclient.discovery import build

#set the translate Service
service = build('translate', 'v2',
        developerKey='AIzaSyATvPo4AatfEvI-NW-stjnnz1YkP5hsD2c')

#This just creates a simple function we can use later.
def translateText(wordList, sourceLang="es", targetLang="en"):
    result=service.translations().list(
        source=sourceLang,
        target=targetLang,
        q=wordList
        ).execute()
    return result

# %%
def clean_tweets(tweet):
 
    stop_words = set(stopwords.words('spanish'))
    word_tokens = word_tokenize(tweet)
#after tweepy preprocessing the colon symbol left remain after      #removing mentions
    tweet = re.sub(r':', '', tweet)
    tweet = re.sub(r'‚Ä¶', '', tweet)
#replace consecutive non-ASCII characters with a space
    tweet = re.sub(r'[^\x00-\x7F]+',' ', tweet)
#remove emojis from tweet
    tweet = emoji_pattern.sub(r'', tweet)
#filter using NLTK library append it to a string
    filtered_tweet = [w for w in word_tokens if not w in stop_words]
    filtered_tweet = []
#looping through conditions
    for w in word_tokens:
#check tokens against stop words , emoticons and punctuations
        if w not in stop_words and w not in emoticons and w not in string.punctuation:
            filtered_tweet.append(w)
    return ' '.join(filtered_tweet)
    #print(word_tokens)
    #print(filtered_sentence)return tweet
